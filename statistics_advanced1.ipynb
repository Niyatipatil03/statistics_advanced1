# %% [markdown]
# Question 1: What is a random variable in probability theory?
#
#
# *   A random variable is a function that assigns a numerical value to each outcome in a sample space of a random experiment. It converts outcomes (which might be qualitative or complex) into numbers so we can apply mathematical methods.
# * Example: when rolling a die,
#
#   the outcome is one of {1,2,3,4,5,6};
#
#    the random variable
#
#   𝑋= value shown is a random variable.

# %% [markdown]
# Question 2: What are the types of random variables?
#
#
# *  Discrete random variables: Take countable distinct values (e.g., number of heads in 10 coin flips, values of a die). They are described by probability mass functions (PMFs).
#
# *  Continuous random variables: Take values in an interval or continuum (e.g., height, weight, measurement errors). They are described by probability density functions (PDFs).

# %% [markdown]
# Question 3: Explain the difference between discrete and continuous distributions.
# * | Basis                          | Discrete Distribution                                                                         | Continuous Distribution                                                                                             |
# | ------------------------------ | --------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------- |
# | **Definition**                 | A discrete distribution deals with random variables that take **countable distinct values**.  | A continuous distribution deals with random variables that can take **any value within a given range or interval**. |
# | **Probability Representation** | Probability is assigned to **specific values** of the variable.                               | Probability is assigned to **intervals** of values, not specific points.                                            |
# | **Probability Function**       | Represented by a **Probability Mass Function (PMF)**, which gives ( P(X = x) ).               | Represented by a **Probability Density Function (PDF)**

# %% [markdown]
# Question 4: What is a binomial distribution, and how is it used in probability?
# * The binomial distribution models the number of successes in
# 𝑛
# n independent Bernoulli trials (each trial has two outcomes: success with probability
# p, failure with probability
# 1−p). The probability of exactly
# k successes is:
#
#   ![image.png](data:image/png;base64,...)
#
# * Use cases: number of defective items in a sample, number of heads in coin tosses, survey responses (yes/no) counts.

# %% [markdown]
# Question 5: What is the standard normal distribution, and why is it important?
# * The standard normal distribution is the normal (Gaussian) distribution with mean 0 and standard deviation 1, usually denoted
# Z∼N(0,1).
#
#   Its PDF is:
#   ![image.png](data:image/png;base64,...)
# * Many statistics (like standardized sample means) are approximately normal due to the Central Limit Theorem.
# * Tables / software provide critical values (e.g.,
# z
# 0.975=1.96) used to compute confidence intervals and hypothesis tests.

# %% [markdown]
# Question 6: What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# * The CLT states that, for a large enough sample size
# n, the sampling distribution of the sample mean
# 𝑋
# ˉ
#  of independent, identically distributed random variables (with finite mean
# μ and finite variance
# σ
# 2
# ) is approximately normal:
# ![image.png](data:image/png;base64,...)
# * Even if the original variable is not normal, the sample mean tends toward normality as
# n increases. Why critical:
#
#   * Justifies using normal-based methods (confidence intervals, hypothesis tests) even when underlying data aren’t normal.
#
#   * Provides a basis for standard errors and inference from samples to populations.

# %% [markdown]
# Question 7: What is the significance of confidence intervals in statistical analysis?
# * A confidence interval (CI) gives a range of plausible values for an unknown population parameter (e.g., the mean) based on sample data and a chosen confidence level (e.g., 95%). Interpretation: a 95% CI means that, under repeated sampling and applying the same CI method, about 95% of such intervals would contain the true parameter. CIs quantify estimation uncertainty and are more informative than a single-point estimate because they show precision and reliability.

# %% [markdown]
# Question 8: What is the concept of expected value in a probability distribution?
# * The expected value (or mean) of a random variable is the long-run average value it would take after many repetitions of the experiment. For a discrete random variable
# X with PMF p(x),
#
#   ![image.png](data:image/png;base64,...)
# * For a continuous random variable with density f(x),
#
#   ![image.png](data:image/png;base64,...)
#
# * Expected value summarizes the center of the distribution and is used in decision making, risk assessment, and as a parameter in many statistical formulas.

# %% [markdown]
# Question 9: Write a Python program to generate 1000 random numbers from a normal
# distribution with mean = 50 and standard deviation = 5. Compute its mean and standard
# deviation using NumPy, and draw a histogram to visualize the distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(42)
data = np.random.normal(loc=50, scale=5, size=1000)
mean_value = np.mean(data)
std_value = np.std(data, ddof=1)
print("Mean of generated data:", mean_value)
print("Standard Deviation of generated data:", std_value)
plt.figure(figsize=(8, 4))
plt.hist(data, bins=30, color='skyblue', edgecolor='black')
plt.title("Histogram of Normal Distribution (mean=50, std=5)")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()
# Out:
# Mean of generated data: 50.096660279111624
# Standard Deviation of generated data: 4.896079690898378

# %% [markdown]
# Question 10: You are working as a data analyst for a retail company. The company has
# collected daily sales data for 2 years and wants you to identify the overall sales trend.
# daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
#  235, 260, 245, 250, 225, 270, 265, 255, 250, 260]
#
# ● Explain how you would apply the Central Limit Theorem to estimate the average sales
# with a 95% confidence interval.
#
# ● Write the Python code to compute the mean sales and its confidence interval.

# %% [markdown]
# * The Central Limit Theorem (CLT) states that when we take repeated samples of size n from any population with mean (μ) and standard deviation (σ), the sampling distribution of the sample mean (x̄) tends to follow a normal distribution as n becomes large, regardless of the shape of the population distribution.
# * In this case:
#
#   * The daily_sales data represents a sample from the population of all possible daily sales.
#
#   * We can use the sample mean (x̄) and sample standard deviation (s) to estimate the population mean (μ).
#
#   * The 95% confidence interval (CI) gives a range within which the true population mean is likely to fall.
#
#   * The formula for a 95% confidence interval of the mean is:
#
#     ![image.png](data:image/png;base64,...)

# %%
import numpy as np
from scipy import stats

# Given daily sales data
daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
               235, 260, 245, 250, 225, 270, 265, 255, 250, 260]

# Convert to numpy array
sales = np.array(daily_sales)

# Calculate mean, standard deviation, and sample size
mean_sales = np.mean(sales)
std_sales = np.std(sales, ddof=1)
n = len(sales)

# Calculate standard error
se = std_sales / np.sqrt(n)

# Calculate t-critical value for 95% confidence level
confidence = 0.95
t_crit = stats.t.ppf((1 + confidence) / 2, df=n - 1)

# Calculate confidence interval
margin_of_error = t_crit * se
lower_limit = mean_sales - margin_of_error
upper_limit = mean_sales + margin_of_error

# Display results
print("Mean Sales:", mean_sales)
print("Standard Deviation:", std_sales)
print("Standard Error:", se)
print("t-critical value:", t_crit)
print(f"95% Confidence Interval: ({lower_limit:.2f}, {upper_limit:.2f})")
# Out:
# Mean Sales: 248.25
# Standard Deviation: 17.26534405284638
# Standard Error: 3.860648295708623
# t-critical value: 2.093024054408263
# 95% Confidence Interval: (240.17, 256.33)
